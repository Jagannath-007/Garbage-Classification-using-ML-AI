# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import os
import shutil
import random
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set dataset directory (update with your actual path)
dataset_dir = "/content/drive/MyDrive/dataset/TrashType_Image_Dataset"

# Define image size and batch size
image_size = (224, 224)  # MobileNetV2 default input size
batch_size = 32
seed = 42

# Create train and validation datasets
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=seed,
    shuffle=True,
    image_size=image_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=seed,
    shuffle=True,
    image_size=image_size,
    batch_size=batch_size
)

# Get class names
class_names = train_ds.class_names
print("Class names:", class_names)
num_classes = len(class_names)
print("Number of classes:", num_classes)

# Split validation set into validation and test sets
val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take(val_batches // 2)
val_ds = val_ds.skip(val_batches // 2)

# Cache and prefetch datasets for better performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# Load MobileNetV2 base model
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Freeze the base model
base_model.trainable = False

# Create the model
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
x = base_model(x, training=False)
x = Dropout(0.2)(x)
outputs = Dense(num_classes, activation='softmax')(x)
model = keras.Model(inputs, outputs)

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
model.summary()

# Calculate class weights (to handle imbalanced classes)
class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(np.concatenate([y for x, y in train_ds], axis=0)),
    y=np.concatenate([y for x, y in train_ds], axis=0)
)
class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# Train the model
epochs = 50
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    class_weight=class_weights,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)

# Plot training history
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

plot_history(history)

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_ds)
print(f'Test accuracy: {test_acc:.4f}')

# Generate predictions
y_pred = []
y_true = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

plot_confusion_matrix(y_true, y_pred, class_names)

# Save the model
model.save('garbage_classifier_mobilenetv2.h5')

# Optional: Fine-tuning
# Unfreeze some layers of the base model for fine-tuning
base_model.trainable = True
# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Recompile the model for fine-tuning
model.compile(
    optimizer=Adam(learning_rate=0.0001),  # Lower learning rate
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Continue training
fine_tune_epochs = 20
total_epochs = len(history.history['loss']) + fine_tune_epochs

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=total_epochs,
    initial_epoch=len(history.history['loss']),
    class_weight=class_weights,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)

# Plot fine-tuning history
plot_history(history_fine)

# Evaluate after fine-tuning
test_loss, test_acc = model.evaluate(test_ds)
print(f'Test accuracy after fine-tuning: {test_acc:.4f}')

# Save the fine-tuned model
model.save('garbage_classifier_mobilenetv2_finetuned.h5')
# Out:
# Mounted at /content/drive
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.
# Class names: ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# Number of classes: 6
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │         7,686 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,265,670 (8.64 MB)
#  Trainable params: 7,686 (30.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Class weights: {0: np.float64(1.0089820359281436), 1: np.float64(0.8446115288220551), 2: np.float64(1.046583850931677), 3: np.float64(0.7154989384288747), 4: np.float64(0.8575063613231552), 5: np.float64(3.2718446601941746)}
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3452 - loss: 1.7260
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - accuracy: 0.3475 - loss: 1.7202 - val_accuracy: 0.7108 - val_loss: 0.8039 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7240 - loss: 0.7891
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.7241 - loss: 0.7889 - val_accuracy: 0.7470 - val_loss: 0.6620 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7784 - loss: 0.6207
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.7782 - loss: 0.6209 - val_accuracy: 0.7992 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.7946 - loss: 0.5608 - val_accuracy: 0.7992 - val_loss: 0.5677 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.8184 - loss: 0.5091 - val_accuracy: 0.7952 - val_loss: 0.5581 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8335 - loss: 0.4544
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.8334 - loss: 0.4548 - val_accuracy: 0.8072 - val_loss: 0.5577 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.8556 - loss: 0.4573 - val_accuracy: 0.8072 - val_loss: 0.5542 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.8513 - loss: 0.4085 - val_accuracy: 0.7912 - val_loss: 0.5752 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8598 - loss: 0.3800 - val_accuracy: 0.8072 - val_loss: 0.5524 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.8724 - loss: 0.3749 - val_accuracy: 0.7952 - val_loss: 0.5709 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8672 - loss: 0.3629 - val_accuracy: 0.7871 - val_loss: 0.5634 - learning_rate: 0.0010
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.8724 - loss: 0.3321 - val_accuracy: 0.7992 - val_loss: 0.5462 - learning_rate: 0.0010
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.8730 - loss: 0.3318 - val_accuracy: 0.8032 - val_loss: 0.5671 - learning_rate: 0.0010
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.8912 - loss: 0.3110 - val_accuracy: 0.7912 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.8760 - loss: 0.3095 - val_accuracy: 0.7871 - val_loss: 0.5428 - learning_rate: 0.0010
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.9041 - loss: 0.2861 - val_accuracy: 0.8032 - val_loss: 0.5451 - learning_rate: 0.0010
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8971 - loss: 0.3011 - val_accuracy: 0.7992 - val_loss: 0.5646 - learning_rate: 0.0010
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.8977 - loss: 0.2939 - val_accuracy: 0.8032 - val_loss: 0.5627 - learning_rate: 0.0010
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.8844 - loss: 0.2974 - val_accuracy: 0.8032 - val_loss: 0.5690 - learning_rate: 0.0010
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.8890 - loss: 0.2889 - val_accuracy: 0.7912 - val_loss: 0.5636 - learning_rate: 0.0010
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.9046 - loss: 0.2629 - val_accuracy: 0.7992 - val_loss: 0.5653 - learning_rate: 1.0000e-04
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.9014 - loss: 0.2563 - val_accuracy: 0.8072 - val_loss: 0.5707 - learning_rate: 1.0000e-04
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.9148 - loss: 0.2442 - val_accuracy: 0.8032 - val_loss: 0.5671 - learning_rate: 1.0000e-04
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.9033 - loss: 0.2699 - val_accuracy: 0.8072 - val_loss: 0.5632 - learning_rate: 1.0000e-04
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.8979 - loss: 0.2534 - val_accuracy: 0.8032 - val_loss: 0.5586 - learning_rate: 1.0000e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8316 - loss: 0.4356
# Test accuracy: 0.8203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#    cardboard       0.97      0.78      0.86        36
#        glass       0.75      0.84      0.79        45
#        metal       0.81      0.81      0.81        43
#        paper       0.88      0.92      0.90        64
#      plastic       0.83      0.78      0.80        49
#        trash       0.60      0.63      0.62        19
#
#     accuracy                           0.82       256
#    macro avg       0.81      0.79      0.80       256
# weighted avg       0.83      0.82      0.82       256
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 26/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.7926 - loss: 0.5907 - val_accuracy: 0.7871 - val_loss: 0.6124 - learning_rate: 1.0000e-04
# Epoch 27/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.8936 - loss: 0.2606 - val_accuracy: 0.6948 - val_loss: 0.8276 - learning_rate: 1.0000e-04
# Epoch 28/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.9317 - loss: 0.1896 - val_accuracy: 0.7068 - val_loss: 0.8805 - learning_rate: 1.0000e-04
# Epoch 29/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.9491 - loss: 0.1491 - val_accuracy: 0.6827 - val_loss: 1.0349 - learning_rate: 1.0000e-04
# Epoch 30/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9746 - loss: 0.0790 - val_accuracy: 0.7108 - val_loss: 0.9710 - learning_rate: 1.0000e-04
# Epoch 31/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9756 - loss: 0.0742 - val_accuracy: 0.6345 - val_loss: 1.3036 - learning_rate: 1.0000e-04
# Epoch 32/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9873 - loss: 0.0502 - val_accuracy: 0.6667 - val_loss: 1.1105 - learning_rate: 1.0000e-05
# Epoch 33/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9842 - loss: 0.0490 - val_accuracy: 0.7309 - val_loss: 0.9466 - learning_rate: 1.0000e-05
# Epoch 34/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9865 - loss: 0.0439 - val_accuracy: 0.7550 - val_loss: 0.8344 - learning_rate: 1.0000e-05
# Epoch 35/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.9870 - loss: 0.0409 - val_accuracy: 0.7671 - val_loss: 0.7406 - learning_rate: 1.0000e-05
# Epoch 36/45
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.9911 - loss: 0.0383 - val_accuracy: 0.7871 - val_loss: 0.6813 - learning_rate: 1.0000e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8028 - loss: 0.5473
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy after fine-tuning: 0.7852
